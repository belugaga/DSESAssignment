# %% [markdown]
# ![IIT_original.png](attachment:IIT_original.png)
# ### <center>  Data Science Essentials (CIA2C14)</center>
# ### <center>  Individual Project</center>

# %% [markdown]
# ### <font color=red>Fill in your personal data below

# %% [markdown]
# #### <font color=blue>Name: Zhang Haorui<font color=black>
# #### <font color=blue>Admin No: 2101806D<font color=black>
# #### <font color=blue>Class: P05<font color=black>

# %% [markdown]
# ### <font color=red> Declaration of Originality
#
# #### I declare that I am the originator of this work and that all other original sources used in this work have been appropriately acknowledged.
#
# #### I understand that plagiarism is the act of taking and using the whole or any part of another person's work and presenting it as my own without proper acknowledgement.
#
# #### I understand that allowing someone else to copy my work and submit it as their own is also considered as plagiarism.
#
# #### I also understand that plagiarism is an academic offence and that disciplinary action will be taken for plagiarism.”
#
# #### Please sign your name or insert a picture of your signature in the markdown cell below. (double click on the cell)

# %% [markdown]
# ![image.png](attachment:1b854bcf-b6d2-4b71-a7b9-c07bd17ac560.png)

# %% [markdown]
# #### 1. This assignment deliverable is worth 45% of the final marks for DSES. The total mark is 90. There are two submissions required- Part I and Part II The due dates are  <font color=red>11 Jul and 07 Aug 2022, 11:59 pm.
# #### 2. For Part I submission, you need to complete Data Understanding and Data Preparation.
# #### 3. For Part II submission, you need to complete Data Modelling, Recommendations & Conclusion.
# #### 4. Note that you should still keep your codes for Part I for tutor to evaluate Part II.
# #### 5. This is an individual deliverable. You are required to produce your own work.
# #### 6. You are allowed to use packages (libraries) not covered in the lecture slides or practicals (e.g. scikit-learn, seaborn, etc.)
# #### 7. Apart from using Markdown cells to include your description, take-aways, and comments, provide sufficient comments to your codes too.
# #### 8. Name your notebook according to the following format.
# >e.g. YourName_2100001A_Assignment
# #### 9. You need to submit your deliverable, i.e. this Jupyter Notebook (.ipynb format) for tutor marking.

# %% [markdown]
# # <font color= maroon> Project Background & Aims

# %% [markdown]
# An airline, called Airline X, have collected data from their passengers' experience with Airline X. The aim is to find out if good service provided on Airline X, in terms of ease of online booking, seat comfort, check-in experience, cleanliness, baggage handling, etc, will contribute to high customer satisfaction level.
# Airline X hopes to serve their customers to the best in time to come and be the choice airline.

# %% [markdown]
# ## <font color= grey> Read CSV from Laptop

# %%
import pandas as pd
import matplotlib.pyplot as plt
airline_data = pd.read_csv('2_AssignmentDataSet.csv')
# Out:
# C:\Users\haoru\AppData\Local\Temp\ipykernel_24040\3753305653.py:3: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   airline_data = pd.read_csv('2_AssignmentDataSet.csv')

# %%
airline_data.describe()
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  103905.000000  103900.000000    103905.000000          103905.000000
# mean    64924.537751      39.387575      1189.444002               2.729686
# std     37463.982357      15.406294       997.159739               1.327961
# min         1.000000      -9.000000        31.000000              -1.000000
# 25%     32534.000000      27.000000       414.000000               2.000000
# 50%     64857.000000      40.000000       843.000000               3.000000
# 75%     97369.000000      51.000000      1743.000000               4.000000
# max    129880.000000     999.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      103903.000000           103903.000000
# mean                            3.060306                2.776185
# std                             1.525148                4.589239
# ...

# %% [markdown]
# ## <font color= grey> Data Understanding

# %% [markdown]
# ### Take-away 1

# %%
airline_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103905 entries, 0 to 103904
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 103905 non-null  int64
#  1   Gender                             103905 non-null  object
#  2   Customer Type                      103905 non-null  object
#  3   Age                                103900 non-null  float64
#  4   Type of Travel                     103905 non-null  object
#  5   Class                              103905 non-null  object
#  6   Flight Distance                    103905 non-null  int64
#  7   Inflight wifi service              103905 non-null  int64
#  8   Departure/Arrival time convenient  103903 non-null  float64
#  9   Ease of Online booking             103903 non-null  float64
#  10  Gate location                      101714 non-null  float64
# ...

# %%
airline_data['Class'].value_counts().plot(kind='pie',autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='Class'>

# %% [markdown]
# From the piechart provided above, 48% of customers were from Business Class, 45% of customers were from Economy Class, and only 7% of customers were from Economy Plus Class.
#
# From the pie-chart, customers from Business Class and Economy Class are well represented. However, customers from Economy Plus Class are not well represented as it represents 7% of the overall customers in the data. In this case, of 103905 customers involved in the dataset, only around 7273 customers are from Economy Plus Class.
#
# In conclusion, with no well representation of Economy Plus Class customers, it may lead to a biased data as the small range of customers from Economy Plus Class may not accurately feedback the customers' experiences when enjoying the facilities or services of Economy Plus Class. This may result in Airline X neglecting customers' experience using Economy Plus Class's facilities and services.

# %% [markdown]
# ### Take-away 2

# %% [markdown]
# #### <font color= blue> Overall Boxplot View

# %%
plt.figure(figsize=(6,4)) #define a space to plot
airline_data[['Age']].boxplot(grid=False, rot=45, fontsize=18) #rotate the labels
plt.title("Boxplot of age of customers in the dataset", fontsize=14)
#plt.ylim([-10,20])
plt.show()

# %% [markdown]
# #### <font color= blue> Range of y-values between -10 and 20

# %%
plt.figure(figsize=(6,4)) #define a space to plot
airline_data[['Age']].boxplot(grid=False, rot=45, fontsize=18) #rotate the labels
plt.title("Boxplot of age of customers in the dataset", fontsize=14)
plt.ylim([-10,20])
plt.show()

# %% [markdown]
# #### <font color= blue> Range of y-values between 900 and 1000

# %%
plt.figure(figsize=(6,4)) #define a space to plot
airline_data[['Age']].boxplot(grid=False, rot=45, fontsize=18) #rotate the labels
plt.title("Boxplot of age of customers in the dataset", fontsize=14)
plt.ylim([900,1000])
plt.show()

# %% [markdown]
# #### <font color= blue> Range of y-values between -10 and 150

# %%
plt.figure(figsize=(6,4)) #define a space to plot
airline_data[['Age']].boxplot(grid=False, rot=45, fontsize=18) #rotate the labels
plt.title("Boxplot of age of customers in the dataset", fontsize=14)
plt.ylim([-10,150])
plt.show()

# %% [markdown]
# From the overall boxplot view provided above, the age range of customers involved in the dataset ranges from ages of around -10 years old to ages of around 1000 years old.
# As seen from the box plot above, the median age of customers in the dataset is approximately 40 years old.
#
# However, there is an extreme outlier value of 1000 years old spotted in the dataset through the box plot and it is hence a wrong and inaccurate data provided.
# Moreover, the box plot also captured the minimum age in this dataset is approximately -10 years old and it is a false data value given as age cannot be a negative value.
#
# As such, data cleaning will be needed to deal with these outliers of unrealistic age number such as 1000 years old or -10 years old as humanity have never experienced such extreme age groups before.

# %% [markdown]
# ### Take-away 3

# %%
#Do a groupby Manufacturer-> Type
#remember to do a unstack to enable plotting using DataFrame syntax

airline_data.groupby(['Type of Travel', 'satisfaction']).size().unstack().plot(kind='bar',stacked=True, figsize=(10,5))
plt.title('Breakdown of Type of Travel by satisfaction')
plt.ylabel('No. of customers')
plt.show()

# %% [markdown]
# As seen from the bar graph above, simple majority of customers in the dataset travels with Airline X for business purposes followed by personal travel.
# - Around 40000 customers, who travelled with Airline X for business travels, are satisfied with their experience on Airline X.
# - Around 30000 customers, who travelled with Airline X for business travels, are neutral or dissatisfied with their experience on Airline X.
#
# From the insights gained above, around 57% of business travellers on Airline X are satisfied with the services on Airline X while the remaining of approximately 43% of business travellers on Airline X are neutral or dissatisified, which is narrow margin of satisfaction rate of services on Airline X as 50% to 60% of satisfaction.

# %% [markdown]
# ### Take-away 4

# %%
airline_data.plot(kind='scatter', x='Flight Distance',y='Departure Delay in Minutes',color='red')
plt.title('Scatter plot', fontsize=18, fontname='Arial')
plt.xlabel('Flight Distance')
plt.ylabel('Departure Delay')
plt.show()

# %% [markdown]
# - As seen from the scatter plot above, most of the departure delays are less than 1000 minutes or approximately 16 hours.
# - There are a few customers who have experienced delays that are in the range of 1000 to 2000 minutes or approximately more than 16 hours but less than 34 hours.
# - There is also a customer who has experienced delay that are more than 7000 minutes or nearly 5 days of delay.
#
# There are a few factors leading to such delays:
# - Air Traffic
# - Weather Conditions
# - Natural/Man-made Disasters
# - Boarding

# %% [markdown]
# ### Take-away 5

# %%
#import pandas as pd
a_count=pd.DataFrame(airline_data['Departure/Arrival time convenient'].value_counts())
a_count
# Out:
#       Departure/Arrival time convenient
#  4.0                              25546
#  5.0                              22404
#  3.0                              17965
#  2.0                              17192
#  1.0                              15494
#  0.0                               5300
# -1.0                                  2

# %%
a_count.plot(kind='bar', color='Green', legend=False)
plt.title('Departure/Arrival time convenient 1', fontsize=18)
plt.xlabel('Rating', fontsize=14)
plt.ylabel('Count',fontsize=14)
plt.show()

# %%
a_count.plot(kind='bar', color='mediumspringgreen', legend=False)
plt.title('Departure/Arrival time convenient 2', fontsize=18)
plt.xlabel('Rating', fontsize=14)
plt.ylabel('Count',fontsize=14)

plt.ylim(-1, 10) #set y limits
#plt.xlim(0, 50) #set x limits
plt.show()

# %% [markdown]
# As seen from the first histogram above, majority of customers gave a rating of 4 (more than 25000) for Departure/Arrival time convenient.
#
# However, as seen from the second histogram, there is an outlier where 2 customers gave a rating of -1, which is out of the scope of rating choices (0 to 5). Thus, data cleaning would be required to remove the negative rating as it is out of the rating scope.
#
# Most ratings are distributed around the mean, which is around 3.06.

# %% [markdown]
# # <font color= maroon>  Data Preparation

# %% [markdown]
# - Perform data cleaning on the identified data quality issues such as missing values, extreme values and encoding for easier process of supervised learning

# %% [markdown]
# ## <font color= grey> Data Cleaning

# %% [markdown]
# ### Check of Missing Values

# %%
#check if there are any missing values

airline_data.isna().sum()
# Out:
# id                                      0
# Gender                                  0
# Customer Type                           0
# Age                                     5
# Type of Travel                          0
# Class                                   0
# Flight Distance                         0
# Inflight wifi service                   0
# Departure/Arrival time convenient       2
# Ease of Online booking                  2
# Gate location                        2191
# Food and drink                          0
# Online boarding                         0
# Seat comfort                            0
# Inflight entertainment                  0
# On-board service                        0
# Leg room service                        0
# Baggage handling                        0
# Checkin service                         0
# Inflight service                        0
# Cleanliness                             0
# Departure Delay in Minutes              0
# ...

# %% [markdown]
# ### Data Cleaning 1 (Age - Missing Values)

# %%
grouped = airline_data.groupby(['Gender', 'Class'])

#show median age
grouped.Age.median()
# Out:
# Gender  Class
# Female  Business    42.0
#         Eco         36.0
#         Eco Plus    37.0
# Male    Business    42.0
#         Eco         37.0
#         Eco Plus    38.0
# Name: Age, dtype: float64

# %%
airline_data[airline_data["id"] == 7070]
# Out:
#          id Gender      Customer Type  Age   Type of Travel     Class  \
# 48380  7070   Male  disloyal Customer  NaN  Business travel  Business
#
#        Flight Distance  Inflight wifi service  \
# 48380              157                      2
#
#        Departure/Arrival time convenient  Ease of Online booking  ...  \
# 48380                                2.0                     2.0  ...
#
#        Inflight entertainment  On-board service  Leg room service  \
# 48380                       2                 4                 4
#
#        Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 48380                 4                4                 4            2
#
#       Departure Delay in Minutes  Arrival Delay in Minutes  \
# 48380                        4.0                      15.0
#
#                   satisfaction
# 48380  neutral or dissatisfied
#
# [1 rows x 24 columns]

# %%
#imputation with correct median age
airline_data['Age'] = grouped.Age.apply(lambda age: age.fillna(age.median()))
            #[] is columns, [[]] is rows

# %%
airline_data['Age'].isna().sum()
# Out:
# 0

# %%
airline_data[airline_data["id"] == 7070]
# Out:
#          id Gender      Customer Type   Age   Type of Travel     Class  \
# 48380  7070   Male  disloyal Customer  42.0  Business travel  Business
#
#        Flight Distance  Inflight wifi service  \
# 48380              157                      2
#
#        Departure/Arrival time convenient  Ease of Online booking  ...  \
# 48380                                2.0                     2.0  ...
#
#        Inflight entertainment  On-board service  Leg room service  \
# 48380                       2                 4                 4
#
#        Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 48380                 4                4                 4            2
#
#       Departure Delay in Minutes  Arrival Delay in Minutes  \
# 48380                        4.0                      15.0
#
#                   satisfaction
# 48380  neutral or dissatisfied
#
# [1 rows x 24 columns]

# %% [markdown]
# Clustering gender and class together to find a median.
#
# Using the median to substitute the missing values.
#
# The reasons of using median instead of mean is that it is safer because median ignores the 2 opposite extreme values and finds a midpoint value after sorting the values from smallest to biggest.

# %% [markdown]
# ### Data Cleaning 2 (Delay - Missing Values)

# %%
airline_data.isna().sum()
# Out:
# id                                      0
# Gender                                  0
# Customer Type                           0
# Age                                     0
# Type of Travel                          0
# Class                                   0
# Flight Distance                         0
# Inflight wifi service                   0
# Departure/Arrival time convenient       2
# Ease of Online booking                  2
# Gate location                        2191
# Food and drink                          0
# Online boarding                         0
# Seat comfort                            0
# Inflight entertainment                  0
# On-board service                        0
# Leg room service                        0
# Baggage handling                        0
# Checkin service                         0
# Inflight service                        0
# Cleanliness                             0
# Departure Delay in Minutes              0
# ...

# %%
airline_data.dropna(subset=['Arrival Delay in Minutes'], inplace=True)

# %%
airline_data.isna().sum()
# Out:
# id                                      0
# Gender                                  0
# Customer Type                           0
# Age                                     0
# Type of Travel                          0
# Class                                   0
# Flight Distance                         0
# Inflight wifi service                   0
# Departure/Arrival time convenient       2
# Ease of Online booking                  2
# Gate location                        2180
# Food and drink                          0
# Online boarding                         0
# Seat comfort                            0
# Inflight entertainment                  0
# On-board service                        0
# Leg room service                        0
# Baggage handling                        0
# Checkin service                         0
# Inflight service                        0
# Cleanliness                             0
# Departure Delay in Minutes              0
# ...

# %% [markdown]
# The missing values in the column Arrival Delay in Minutes is removed from the dataset as these are accurate data that the customers have experienced on that flight. As it is not accurate for programmers to assume such numerical data, the row that contained the missing values of Arrival Delay in Muniutes is removed.

# %% [markdown]
# ### Data Cleaning 3 (Gate Location - Missing Values)

# %%
airline_data.dropna(subset=['Gate location'], inplace=True)

# %%
airline_data.isna().sum()
# Out:
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    2
# Ease of Online booking               2
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         5
# dtype: int64

# %% [markdown]
# The missing values in the column Gate location is removed from the dataset as these are accurate data that the customers have experienced at the particular facility at a particular timing. As it might be biased for programmers to assume such numerical data, the row that contained the missing values of Gate location is removed.

# %% [markdown]
# ### Data Cleaning 4 (Satisfaction - Missing Values)

# %%
airline_data.dropna(subset=['satisfaction'], inplace=True)

# %%
airline_data.isna().sum()
# Out:
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    2
# Ease of Online booking               2
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %% [markdown]
# The missing values in the column satisfaction is removed from the dataset as these are accurate data that the customers have rated their overall airline satisfaction. As it is not accurate for programmers to assume such ratings given by the customers, the row that contained the missing values of satisfaction is removed.

# %% [markdown]
# ### Data Cleaning 5 (Departure/Arrival time convenient & Ease of Online booking - Missing Values)

# %%
airline_data.dropna(subset=['Departure/Arrival time convenient'], inplace=True)

# %%
airline_data.dropna(subset=['Ease of Online booking'], inplace=True)

# %%
airline_data.isna().sum()
# Out:
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %% [markdown]
# The missing values in the columns Departure/Arrival time convenient & Ease of Online booking are removed from the dataset as these are accurate data that the customers have experienced on that flight. As it is biased for programmers to assume such numerical data that customers themselves experienced, the row that contained the missing values of Arrival Delay in Muniutes is removed.

# %% [markdown]
# ### Data Cleaning 6 (Age - Extreme Values)

# %%
#check if there are any missing values

airline_data.describe()
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  101406.000000  101406.000000    101406.000000          101406.000000
# mean    64924.385825      39.379839      1189.065558               2.729424
# std     37450.003617      15.414259       997.375799               1.327576
# min         1.000000      -9.000000        31.000000              -1.000000
# 25%     32554.250000      27.000000       413.000000               2.000000
# 50%     64880.500000      40.000000       842.000000               3.000000
# 75%     97341.750000      51.000000      1744.000000               4.000000
# max    129880.000000     999.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      101406.000000           101406.000000
# mean                            3.059385                2.775822
# std                             1.525570                4.640144
# ...

# %%
airline_data['Age'].replace(999, 85, inplace=True)

# %%
airline_data['Age'].replace(-9, 7, inplace=True)

# %%
airline_data['Age'].replace(-1, 7, inplace=True)

# %%
airline_data.describe()
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  101406.000000  101406.000000    101406.000000          101406.000000
# mean    64924.385825      39.371063      1189.065558               2.729424
# std     37450.003617      15.116886       997.375799               1.327576
# min         1.000000       7.000000        31.000000              -1.000000
# 25%     32554.250000      27.000000       413.000000               2.000000
# 50%     64880.500000      40.000000       842.000000               3.000000
# 75%     97341.750000      51.000000      1744.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      101406.000000           101406.000000
# mean                            3.059385                2.775822
# std                             1.525570                4.640144
# ...

# %% [markdown]
# The second tranformation is to impute the value of customer's age by imputing those ages of extreme outliers such as ages that are 999 years old or -9 years old as such ages does not exist according to domain knowledge.
#
# Those values are imputed either to the next highest age which is 85 years old or to the smallest positive integer found in the age column which is 7 years old.
#
# It is better way to clean the age column data is to substitute the extreme values with the next possible minimum or maximum value as age cannot be more than 100 or less than 0. Assuming that there is human error (assumption made up by somebody) may be a risky move and can result in a biased and unreliable data.

# %% [markdown]
# ### Data Cleaning 7 (Inflight wifi service - Extreme Values)

# %%
airline_data[airline_data["Inflight wifi service"] < 0]
# Out:
#         id Gender   Customer Type   Age   Type of Travel     Class  \
# 398  17284   Male  Loyal Customer  32.0  Business travel  Business
# 627  78234   Male  Loyal Customer  53.0  Business travel  Business
# 628  23979   Male  Loyal Customer  52.0  Business travel  Business
#
#      Flight Distance  Inflight wifi service  \
# 398             3607                     -1
# 627             1741                     -1
# 628             3092                     -1
#
#      Departure/Arrival time convenient  Ease of Online booking  ...  \
# 398                                1.0                     1.0  ...
# 627                                1.0                     1.0  ...
# 628                                1.0                     1.0  ...
#
#      Inflight entertainment  On-board service  Leg room service  \
# 398                       5                 4                 2
# 627                       4                 4                 4
# ...

# %%
airline_data.drop([398,627,628],inplace=True)

# %%
airline_data.describe()
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  101403.000000  101403.000000    101403.000000          101403.000000
# mean    64925.128172      39.370877      1189.017504               2.729535
# std     37450.014700      15.116979       997.342238               1.327440
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32555.500000      27.000000       413.000000               2.000000
# 50%     64881.000000      40.000000       842.000000               3.000000
# 75%     97343.000000      51.000000      1744.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      101403.000000           101403.000000
# mean                            3.059446                2.775874
# std                             1.525552                4.640203
# ...

# %% [markdown]
# The extreme values in the column Inflight wifi service is removed from the dataset as these are ratings that are out of the scope of 0 to 5. Mean or median of such ratings are not used as it is biased to assume such numerical data that customers themselves experienced. Hence, the row that contained the missing values of Inflight wifi service is removed for the reliabilty of the data.

# %% [markdown]
# ### Data Cleaning 8 (Departure/Arrival time convenient - Extreme Values)

# %%
airline_data[airline_data["Departure/Arrival time convenient"] < 0]
# Out:
#           id  Gender      Customer Type   Age   Type of Travel Class  \
# 51970  27663  Female  disloyal Customer  36.0  Business travel   Eco
#
#        Flight Distance  Inflight wifi service  \
# 51970             1216                      1
#
#        Departure/Arrival time convenient  Ease of Online booking  ...  \
# 51970                               -1.0                     1.0  ...
#
#        Inflight entertainment  On-board service  Leg room service  \
# 51970                       5                 4                 3
#
#        Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 51970                 4                5                 4            5
#
#       Departure Delay in Minutes  Arrival Delay in Minutes  \
# 51970                       48.0                      44.0
#
#                   satisfaction
# 51970  neutral or dissatisfied
#
# [1 rows x 24 columns]

# %%
airline_data.drop([51970],inplace=True)

# %%
airline_data.describe()
# Out:
#                   id           Age  Flight Distance  Inflight wifi service  \
# count  101402.000000  101402.00000    101402.000000          101402.000000
# mean    64925.495641      39.37091      1189.017238               2.729552
# std     37450.016547      15.11705       997.347153               1.327436
# min         1.000000       7.00000        31.000000               0.000000
# 25%     32556.250000      27.00000       413.000000               2.000000
# 50%     64882.000000      40.00000       842.000000               3.000000
# 75%     97343.500000      51.00000      1744.000000               4.000000
# max    129880.000000      85.00000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      101402.000000           101402.000000
# mean                            3.059486                2.775892
# std                             1.525506                4.640222
# ...

# %% [markdown]
# The extreme values in the column Departure/Arrival time convenient is removed from the dataset as these are ratings that are out of the scope of 0 to 5. Mean or median of such ratings are not used as it is biased to assume such numerical data that customers themselves experienced. Hence, the row that contained the missing values of Departure/Arrival time convenient is removed for the reliabilty of the data.

# %% [markdown]
# ### Data Cleaning 9 (Ease of Online booking - Extreme Values)

# %%
airline_data[airline_data["Ease of Online booking"] > 5]
# Out:
#            id  Gender   Customer Type   Age   Type of Travel     Class  \
# 53675    4696  Female  Loyal Customer  38.0  Personal Travel       Eco
# 103880  59339  Female  Loyal Customer  30.0  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 53675               364                      1
# 103880             2338                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  ...  \
# 53675                                 5.0                   999.0  ...
# 103880                                1.0                   999.0  ...
#
#         Inflight entertainment  On-board service  Leg room service  \
# 53675                        2                 5                 3
# 103880                       4                 3                 4
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 53675                  4                4                 5            2
# ...

# %%
airline_data.drop([53675,103880],inplace=True)

# %%
airline_data.describe()
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  101400.000000  101400.000000    101400.000000          101400.000000
# mean    64926.144714      39.371016      1189.014043               2.729586
# std     37449.904123      15.117169       997.347096               1.327427
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32556.750000      27.000000       413.000000               2.000000
# 50%     64883.500000      40.000000       842.000000               3.000000
# 75%     97344.250000      51.000000      1744.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      101400.000000           101400.000000
# mean                            3.059487                2.756243
# std                             1.525495                1.398682
# ...

# %% [markdown]
# The extreme values in the column Ease of Online booking is removed from the dataset as these are ratings that are out of the scope of 0 to 5. Mean or median of such ratings are not used as it is inaccurate to assume such numerical data that customers themselves experienced. Hence, the row that contained the missing values of Ease of Online booking is removed for the reliabilty of the data.

# %% [markdown]
# ### Data Cleaning 10 (Arrival Delay in Minutes - Extreme Values)

# %%
airline_data[airline_data["Arrival Delay in Minutes"] > 5000]
# Out:
#           id  Gender   Customer Type   Age   Type of Travel     Class  \
# 94452  95510  Female  Loyal Customer  37.0  Business travel  Eco Plus
#
#        Flight Distance  Inflight wifi service  \
# 94452              323                      3
#
#        Departure/Arrival time convenient  Ease of Online booking  ...  \
# 94452                                3.0                     3.0  ...
#
#        Inflight entertainment  On-board service  Leg room service  \
# 94452                       3                 4                 2
#
#        Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 94452                 3                4                 3            3
#
#       Departure Delay in Minutes  Arrival Delay in Minutes  \
# 94452                       20.0                12000000.0
#
#                   satisfaction
# 94452  neutral or dissatisfied
#
# [1 rows x 24 columns]

# %%
airline_data.describe()
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  101400.000000  101400.000000    101400.000000          101400.000000
# mean    64926.144714      39.371016      1189.014043               2.729586
# std     37449.904123      15.117169       997.347096               1.327427
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32556.750000      27.000000       413.000000               2.000000
# 50%     64883.500000      40.000000       842.000000               3.000000
# 75%     97344.250000      51.000000      1744.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      101400.000000           101400.000000
# mean                            3.059487                2.756243
# std                             1.525495                1.398682
# ...

# %%
airline_data.drop([94452], inplace=True)

# %%
airline_data.describe()
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  101399.000000  101399.000000    101399.000000          101399.000000
# mean    64925.843095      39.371039      1189.022584               2.729583
# std     37449.965628      15.117242       997.348306               1.327433
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32556.500000      27.000000       413.000000               2.000000
# 50%     64883.000000      40.000000       842.000000               3.000000
# 75%     97344.500000      51.000000      1744.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      101399.000000           101399.000000
# mean                            3.059488                2.756240
# std                             1.525503                1.398689
# ...

# %% [markdown]
# The extreme values in the column Arrival Delay in Minutes is removed from the dataset as 12000000 minutes is approximately equivalent to 8333 days or 22.82 years. These arrival delays are not feasible due to the extremely long years, which no one has experienced before. As such, the row that contained the extreme value of Arrival Delay in Minutes is removed for the feasibility of the data.

# %% [markdown]
# ### Data Cleaning 11 (Baggage handling - Wrong Values)

# %%
airline_data.nunique()
# Out:
# id                                   101397
# Gender                                    2
# Customer Type                             6
# Age                                      75
# Type of Travel                            2
# Class                                     3
# Flight Distance                        3800
# Inflight wifi service                     6
# Departure/Arrival time convenient         6
# Ease of Online booking                    6
# Gate location                             6
# Food and drink                            6
# Online boarding                           6
# Seat comfort                              6
# Inflight entertainment                    6
# On-board service                          6
# Leg room service                          6
# Baggage handling                         11
# Checkin service                           6
# Inflight service                          6
# Cleanliness                               6
# ...

# %%
airline_data['Baggage handling'].dtype
# Out:
# dtype('O')

# %%
airline_data['Baggage handling'].unique()
# Out:
# array(['4', '3', '5', '1', '2', '-', 5, 3, 4, 2, 1], dtype=object)

# %%
airline_data['Baggage handling'].replace('-', 0, inplace=True)

# %%
airline_data['Baggage handling'].replace('4', 4, inplace=True)

# %%
airline_data['Baggage handling'].replace('3', 3, inplace=True)

# %%
airline_data['Baggage handling'].replace('5', 5, inplace=True)

# %%
airline_data['Baggage handling'].replace('1', 1, inplace=True)

# %%
airline_data['Baggage handling'].replace('2', 2, inplace=True)

# %%
airline_data['Baggage handling'].unique()
# Out:
# array([4, 3, 5, 1, 2, 0], dtype=int64)

# %%
airline_data.nunique()
# Out:
# id                                   101397
# Gender                                    2
# Customer Type                             6
# Age                                      75
# Type of Travel                            2
# Class                                     3
# Flight Distance                        3800
# Inflight wifi service                     6
# Departure/Arrival time convenient         6
# Ease of Online booking                    6
# Gate location                             6
# Food and drink                            6
# Online boarding                           6
# Seat comfort                              6
# Inflight entertainment                    6
# On-board service                          6
# Leg room service                          6
# Baggage handling                          6
# Checkin service                           6
# Inflight service                          6
# Cleanliness                               6
# ...

# %% [markdown]
# The string datatypes in the column Baggage handling is replaced to a respective integer datatypes with the exception of '-'.
# This to ensure that the datatype of the columns must remain consistent of having integer datatypes. Integer datatypes is also needed for machine learning and plotting of charts for visual analysis.
#
# The string datatype '-' is replaced to an integer datatype of 0.
# Since '-' in the understanding of human terms as NA, meaning not applicable, it can be represented with an integer 0 as 0 represents not applicable, meaning that the customers who is involved in the survey did not want to rate on this service becuase of personal reasons.

# %% [markdown]
# ### Data Cleaning 12 (Class - Combination of Eco & Eco Plus)

# %%
airline_data['Class'].unique()
# Out:
# array(['Eco Plus', 'Business', 'Eco'], dtype=object)

# %%
airline_data.head()
# Out:
#        id  Gender      Customer Type   Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer  13.0  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer  25.0  Business travel  Business
# 2  110028  Female     Loyal Customer  26.0  Business travel  Business
# 3   24026  Female     Loyal Customer  25.0  Business travel  Business
# 4  119299    Male     Loyal Customer  61.0  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                4.0
# 1              235                      3                                2.0
# 2             1142                      2                                2.0
# 3              562                      2                                5.0
# 4              214                      3                                3.0
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# ...

# %%
airline_data['Class'].replace('Eco Plus', 'Eco', inplace=True)

# %%
airline_data.head()
# Out:
#        id  Gender      Customer Type   Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer  13.0  Personal Travel       Eco
# 1    5047    Male  disloyal Customer  25.0  Business travel  Business
# 2  110028  Female     Loyal Customer  26.0  Business travel  Business
# 3   24026  Female     Loyal Customer  25.0  Business travel  Business
# 4  119299    Male     Loyal Customer  61.0  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                4.0
# 1              235                      3                                2.0
# 2             1142                      2                                2.0
# 3              562                      2                                5.0
# 4              214                      3                                3.0
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# ...

# %%
airline_data['Class'].unique()
# Out:
# array(['Eco', 'Business'], dtype=object)

# %% [markdown]
# The combination of Eco & Eco Plus to Eco in the column Class is handled. As seen earlier in Take-away 1, the number of customers involved in the dataset from Eco Plus has a very small proportion of represenation and is disproportionate as a result. Hence, it is not representaitve for Airline X to improve on Eco Plus services as it has not gathered enough customers to feedback on their experience in Eco Plus.
# As such, replacing Eco Plus to Eco class is more representative to be able to give insights on the services with Airline X.

# %% [markdown]
# ## <font color= grey> Data Transformation

# %% [markdown]
# Transforming the data to encoding/binning

# %% [markdown]
# ### Transformation 1 (Delay - Combining Columns)

# %%
#check if there are any missing values

airline_data.describe()
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  101399.000000  101399.000000    101399.000000          101399.000000
# mean    64925.843095      39.371039      1189.022584               2.729583
# std     37449.965628      15.117242       997.348306               1.327433
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32556.500000      27.000000       413.000000               2.000000
# 50%     64883.000000      40.000000       842.000000               3.000000
# 75%     97344.500000      51.000000      1744.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      101399.000000           101399.000000
# mean                            3.059488                2.756240
# std                             1.525503                1.398689
# ...

# %%
airline_data['Overall Delay'] = airline_data['Departure Delay in Minutes'] + airline_data['Arrival Delay in Minutes']

# %%
del airline_data['Departure Delay in Minutes']

# %%
del airline_data['Arrival Delay in Minutes']

# %%
airline_data.describe()
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  101399.000000  101399.000000    101399.000000          101399.000000
# mean    64925.843095      39.371039      1189.022584               2.729583
# std     37449.965628      15.117242       997.348306               1.327433
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32556.500000      27.000000       413.000000               2.000000
# 50%     64883.000000      40.000000       842.000000               3.000000
# 75%     97344.500000      51.000000      1744.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      101399.000000           101399.000000
# mean                            3.059488                2.756240
# std                             1.525503                1.398689
# ...

# %% [markdown]
# Since Departure Delay and Arrival Delay are generalisations of aircraft delays in the aviation industry, both the column values of Departure Delay and Arrvival Delay will be added and combined to form a new column called Overall Delay.
#
# The Overall Delay column will represent the total delay held up by the airline on the flight the customer experienced.

# %% [markdown]
# ### Transformation 2 (Flight Distance - Encoding)

# %%
def myfunc(x):
    if x < 700:
        return '1'
    elif x >= 700 and x <= 3000:
        return '2'
    else:
        return '3'

airline_data_distance=airline_data.assign(Distance_Code = lambda x:airline_data['Flight Distance'].apply(myfunc))
                                                                                  
#preview
airline_data_distance.tail()
# Out:
#            id  Gender      Customer Type   Age   Type of Travel     Class  \
# 103899  60666    Male     Loyal Customer  50.0  Personal Travel       Eco
# 103900  94171  Female  disloyal Customer  23.0  Business travel       Eco
# 103901  73097    Male     Loyal Customer  49.0  Business travel  Business
# 103903  54173  Female  disloyal Customer  22.0  Business travel       Eco
# 103904  62567    Male     Loyal Customer  27.0  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 103899             1620                      3
# 103900              192                      2
# 103901             2347                      4
# 103903             1000                      1
# 103904             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  ...  \
# 103899                                1.0                     3.0  ...
# 103900                                1.0                     2.0  ...
# ...

# %%
#del airline_data_distance['Flight Distance']

# %%
airline_data_distance.tail()
# Out:
#            id  Gender      Customer Type   Age   Type of Travel     Class  \
# 103899  60666    Male     Loyal Customer  50.0  Personal Travel       Eco
# 103900  94171  Female  disloyal Customer  23.0  Business travel       Eco
# 103901  73097    Male     Loyal Customer  49.0  Business travel  Business
# 103903  54173  Female  disloyal Customer  22.0  Business travel       Eco
# 103904  62567    Male     Loyal Customer  27.0  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 103899             1620                      3
# 103900              192                      2
# 103901             2347                      4
# 103903             1000                      1
# 103904             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  ...  \
# 103899                                1.0                     3.0  ...
# 103900                                1.0                     2.0  ...
# ...

# %% [markdown]
# Encoding Flight Distance to 1 (Short Haul), 2 (Medium Haul), 3 (Long Haul) is more understandable as the long travelling distance on airplane might not be known to all people. As such, non-industry viewers viewing the graph may be able to understand the graph easier.

# %% [markdown]
# ### Transformation 3 (Gender - Encoding)

# %%
def myfunc(x):
    if x == 'Female':
        return 0
    else:
        return 1

airline_data_gender=airline_data_distance.assign(Gender_Code = lambda x:airline_data_distance['Gender'].apply(myfunc))
                                                                                  
#preview
airline_data_gender.tail()
# Out:
#            id  Gender      Customer Type   Age   Type of Travel     Class  \
# 103899  60666    Male     Loyal Customer  50.0  Personal Travel       Eco
# 103900  94171  Female  disloyal Customer  23.0  Business travel       Eco
# 103901  73097    Male     Loyal Customer  49.0  Business travel  Business
# 103903  54173  Female  disloyal Customer  22.0  Business travel       Eco
# 103904  62567    Male     Loyal Customer  27.0  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 103899             1620                      3
# 103900              192                      2
# 103901             2347                      4
# 103903             1000                      1
# 103904             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  ...  \
# 103899                                1.0                     3.0  ...
# 103900                                1.0                     2.0  ...
# ...

# %%
del airline_data_gender['Gender']

# %%
airline_data_gender.head()
# Out:
#        id      Customer Type   Age   Type of Travel     Class  \
# 0   70172     Loyal Customer  13.0  Personal Travel       Eco
# 1    5047  disloyal Customer  25.0  Business travel  Business
# 2  110028     Loyal Customer  26.0  Business travel  Business
# 3   24026     Loyal Customer  25.0  Business travel  Business
# 4  119299     Loyal Customer  61.0  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                4.0
# 1              235                      3                                2.0
# 2             1142                      2                                2.0
# 3              562                      2                                5.0
# 4              214                      3                                3.0
#
#    Ease of Online booking  Gate location  ...  On-board service  \
# ...

# %% [markdown]
# Encoding Gender to 0 (Female) and 1 (Male) will be better for machine learning as the machine will be able to learn through numerical values rather than categorical values.

# %% [markdown]
# ### Transformation 4 (Satisfaction - Encoding)

# %%
def myfunc(x):
    if x == 'satisfied':
        return 1
    else:
        return 0

airline_data_satisfaction=airline_data_gender.assign(Satisfaction_Code = lambda x:airline_data_gender['satisfaction'].apply(myfunc))
                                                                                  
#preview
airline_data_satisfaction.tail()
# Out:
#            id      Customer Type   Age   Type of Travel     Class  \
# 103899  60666     Loyal Customer  50.0  Personal Travel       Eco
# 103900  94171  disloyal Customer  23.0  Business travel       Eco
# 103901  73097     Loyal Customer  49.0  Business travel  Business
# 103903  54173  disloyal Customer  22.0  Business travel       Eco
# 103904  62567     Loyal Customer  27.0  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 103899             1620                      3
# 103900              192                      2
# 103901             2347                      4
# 103903             1000                      1
# 103904             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 103899                                1.0                     3.0
# 103900                                1.0                     2.0
# 103901                                4.0                     4.0
# ...

# %%
del airline_data_satisfaction['satisfaction']

# %%
airline_data_satisfaction.tail()
# Out:
#            id      Customer Type   Age   Type of Travel     Class  \
# 103899  60666     Loyal Customer  50.0  Personal Travel       Eco
# 103900  94171  disloyal Customer  23.0  Business travel       Eco
# 103901  73097     Loyal Customer  49.0  Business travel  Business
# 103903  54173  disloyal Customer  22.0  Business travel       Eco
# 103904  62567     Loyal Customer  27.0  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 103899             1620                      3
# 103900              192                      2
# 103901             2347                      4
# 103903             1000                      1
# 103904             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 103899                                1.0                     3.0
# 103900                                1.0                     2.0
# 103901                                4.0                     4.0
# ...

# %% [markdown]
# Encoding satifaction column to 0 (neutral or dissatisfied) and 1 (satisfied) will be easier when using machine learning to learn the relationships between the factors attributing to the satisfaction values.

# %% [markdown]
# ### Transformation 5 (Customer Type - Binning)

# %%
airline_data['Customer Type'].unique()
# Out:
# array(['Loyal Customer', 'disloyal Customer', 'loyal', 'Disloyal',
#        'DISLOYAL CUSTOMER', 'Disloyal Customer'], dtype=object)

# %%
airline_data_loyalty=airline_data_satisfaction.assign(is_Loyal = lambda x:airline_data_satisfaction['Customer Type'].str.contains('^loyal', case=False))
                                                                                  
#preview
airline_data_loyalty.tail()
# Out:
#            id      Customer Type   Age   Type of Travel     Class  \
# 103899  60666     Loyal Customer  50.0  Personal Travel       Eco
# 103900  94171  disloyal Customer  23.0  Business travel       Eco
# 103901  73097     Loyal Customer  49.0  Business travel  Business
# 103903  54173  disloyal Customer  22.0  Business travel       Eco
# 103904  62567     Loyal Customer  27.0  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 103899             1620                      3
# 103900              192                      2
# 103901             2347                      4
# 103903             1000                      1
# 103904             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 103899                                1.0                     3.0
# 103900                                1.0                     2.0
# 103901                                4.0                     4.0
# ...

# %%
del airline_data_loyalty['Customer Type']

# %%
airline_data_loyalty.tail()
# Out:
#            id   Age   Type of Travel     Class  Flight Distance  \
# 103899  60666  50.0  Personal Travel       Eco             1620
# 103900  94171  23.0  Business travel       Eco              192
# 103901  73097  49.0  Business travel  Business             2347
# 103903  54173  22.0  Business travel       Eco             1000
# 103904  62567  27.0  Business travel  Business             1723
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# 103899                      3                                1.0
# 103900                      2                                1.0
# 103901                      4                                4.0
# 103903                      1                                1.0
# 103904                      1                                3.0
#
#         Ease of Online booking  Gate location  Food and drink  ...  \
# 103899                     3.0            4.0               2  ...
# ...

# %% [markdown]
# Binning Customer Type column to boolean dataype values such as True (Loyal Customer) and False (Disloyal Customer) is easier as there were 6 unique values found in the Customer Type column. As the column is meant to have 2 unique values instead for easier understanding, binning customer type will remove confusion and unnecessary complications.

# %% [markdown]
# ### Transformation 6 (Type of Travel - Encoding)

# %%
def myfunc(x):
    if x == 'Personal Travel':
        return 1
    else:
        return 0

airline_data_type=airline_data_loyalty.assign(Travel_Type = lambda x:airline_data_loyalty['Type of Travel'].apply(myfunc))

airline_data_type.head()
# Out:
#        id   Age   Type of Travel     Class  Flight Distance  \
# 0   70172  13.0  Personal Travel       Eco              460
# 1    5047  25.0  Business travel  Business              235
# 2  110028  26.0  Business travel  Business             1142
# 3   24026  25.0  Business travel  Business              562
# 4  119299  61.0  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                4.0
# 1                      3                                2.0
# 2                      2                                2.0
# 3                      2                                5.0
# 4                      3                                3.0
#
#    Ease of Online booking  Gate location  Food and drink  ...  \
# 0                     3.0            1.0               5  ...
# 1                     3.0            3.0               1  ...
# ...

# %%
del airline_data_type['Type of Travel']

# %%
airline_data_type.head()
# Out:
#        id   Age     Class  Flight Distance  Inflight wifi service  \
# 0   70172  13.0       Eco              460                      3
# 1    5047  25.0  Business              235                      3
# 2  110028  26.0  Business             1142                      2
# 3   24026  25.0  Business              562                      2
# 4  119299  61.0  Business              214                      3
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                4.0                     3.0            1.0
# 1                                2.0                     3.0            3.0
# 2                                2.0                     2.0            2.0
# 3                                5.0                     5.0            5.0
# 4                                3.0                     3.0            3.0
#
#    Food and drink  Online boarding  ...  Baggage handling  Checkin service  \
# ...

# %% [markdown]
# Encoding the type of travel to 0 (Business Travel) and 1 (Personal Travel) will be easier when using machine learning to learn and intepret the numerical values from the types of travel.

# %% [markdown]
# ### Transformation 7 (Class - Encoding)

# %%
def myfunc(x):
    if x == 'Eco':
        return 0
    else:
        return 1

airline_data_class=airline_data_type.assign(Class_Type = lambda x:airline_data_type['Class'].apply(myfunc))

airline_data_class.head()
# Out:
#        id   Age     Class  Flight Distance  Inflight wifi service  \
# 0   70172  13.0       Eco              460                      3
# 1    5047  25.0  Business              235                      3
# 2  110028  26.0  Business             1142                      2
# 3   24026  25.0  Business              562                      2
# 4  119299  61.0  Business              214                      3
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                4.0                     3.0            1.0
# 1                                2.0                     3.0            3.0
# 2                                2.0                     2.0            2.0
# 3                                5.0                     5.0            5.0
# 4                                3.0                     3.0            3.0
#
#    Food and drink  Online boarding  ...  Checkin service  Inflight service  \
# ...

# %%
del airline_data_class['Class']

# %%
airline_data_class.head()
# Out:
#        id   Age  Flight Distance  Inflight wifi service  \
# 0   70172  13.0              460                      3
# 1    5047  25.0              235                      3
# 2  110028  26.0             1142                      2
# 3   24026  25.0              562                      2
# 4  119299  61.0              214                      3
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                4.0                     3.0            1.0
# 1                                2.0                     3.0            3.0
# 2                                2.0                     2.0            2.0
# 3                                5.0                     5.0            5.0
# 4                                3.0                     3.0            3.0
#
#    Food and drink  Online boarding  Seat comfort  ...  Checkin service  \
# 0               5                3             5  ...                4
# ...

# %% [markdown]
# Encoding the column Class to 0 (Eco) and 1 (Business) will be easier when using machine learning to learn and visualise the numerical vaalues from the Class types the customers were experiencing Airline X's services.

# %% [markdown]
# ### Removal of id

# %%
df_updated = airline_data_class.drop(labels='id', axis=1)

# %%
df_updated.head()
# Out:
#     Age  Flight Distance  Inflight wifi service  \
# 0  13.0              460                      3
# 1  25.0              235                      3
# 2  26.0             1142                      2
# 3  25.0              562                      2
# 4  61.0              214                      3
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                4.0                     3.0            1.0
# 1                                2.0                     3.0            3.0
# 2                                2.0                     2.0            2.0
# 3                                5.0                     5.0            5.0
# 4                                3.0                     3.0            3.0
#
#    Food and drink  Online boarding  Seat comfort  Inflight entertainment  ...  \
# 0               5                3             5                       5  ...
# ...

# %%
df_updated.nunique()
# Out:
# Age                                    75
# Flight Distance                      3800
# Inflight wifi service                   6
# Departure/Arrival time convenient       6
# Ease of Online booking                  6
# Gate location                           6
# Food and drink                          6
# Online boarding                         6
# Seat comfort                            6
# Inflight entertainment                  6
# On-board service                        6
# Leg room service                        6
# Baggage handling                        6
# Checkin service                         6
# Inflight service                        6
# Cleanliness                             6
# Overall Delay                         766
# Distance_Code                           3
# Gender_Code                             2
# Satisfaction_Code                       2
# is_Loyal                                2
# Travel_Type                             2
# ...

# %% [markdown]
# id column is removed from the dataset as id is used to identify the customers who are involved in the survey. As such, there is no need to keep id column as there is no pattern or relationship found hence is not useful to keep id column.

# %% [markdown]
# ## <font color= grey> Correlation Analysis

# %%
corr_mat = airline_data_class.corr()
corr_mat.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_18f19_row0_col0, #T_18f19_row1_col1, #T_18f19_row2_col2, #T_18f19_row3_col3, #T_18f19_row4_col4, #T_18f19_row5_col5, #T_18f19_row6_col6, #T_18f19_row7_col7, #T_18f19_row8_col8, #T_18f19_row9_col9, #T_18f19_row10_col10, #T_18f19_row11_col11, #T_18f19_row12_col12, #T_18f19_row13_col13, #T_18f19_row14_col14, #T_18f19_row15_col15, #T_18f19_row16_col16, #T_18f19_row17_col17, #T_18f19_row18_col18, #T_18f19_row19_col19, #T_18f19_row20_col20, #T_18f19_row21_col21, #T_18f19_row22_col22 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_18f19_row0_col1, #T_18f19_row1_col14, #T_18f19_row2_col4, #T_18f19_row6_col16, #T_18f19_row7_col1, #T_18f19_row12_col0 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_18f19_row0_col2, #T_18f19_row3_col21 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_18f19_row0_col3, #T_18f19_row3_col14, #T_18f19_row9_col0, #T_18f19_row13_col18, #T_18f19_row15_col18 {
#   background-color: #fee8de;
# ...

# %% [markdown]
# Provide the description, justification and results of your technique(s) here.

# %% [markdown]
# The above chart is a correlation heatmap of the dataset of Airline X after cleaning and transformation.
#
# The correlation heatmap is used as it is a graphical representation of a correlation matrix representing the correlation between different variables. Hence, every variable correlation value can be seen from one heatmap, which is very convenient and efficient to gather which variables has a relationship between another variable.
#
# Variables selected:
# - Ease of Online booking
# - Inflight wifi service
# - Inflight entertainment
# - Food and drink
# - Cleanliness
# - Seat comfort
# - Baggage handling
# - Satisfaction_Code

# %% [markdown]
# ## <font color= grey> Your Other Method

# %%
airline_data_class[['Ease of Online booking']].skew()
# Out:
# Ease of Online booking   -0.017336
# dtype: float64

# %%
airline_data_class[['Ease of Online booking']].kurt()
# Out:
# Ease of Online booking   -0.909802
# dtype: float64

# %% [markdown]
# The above chart is a simple test of normality.
#
# - Compare the values against the Gaussian's (Normal Distribution) ones (kurt=0, skew=0).
# - This distribution of this attribute deviates not so significantly from the Normal distribution.
# - Tallies with the visual inspection that the attribute is negatively skewed.
# - No extreme values were found due to low kertosis.

# %% [markdown]
# # <font color= maroon> Data Modelling

# %% [markdown]
# - Flight Distance was decided to not be removed for data modelling section.

# %%
df_final = df_updated.drop(columns='Distance_Code')

pd.set_option('display.max_columns', None)
df_final.head()
# Out:
#     Age  Flight Distance  Inflight wifi service  \
# 0  13.0              460                      3
# 1  25.0              235                      3
# 2  26.0             1142                      2
# 3  25.0              562                      2
# 4  61.0              214                      3
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                4.0                     3.0            1.0
# 1                                2.0                     3.0            3.0
# 2                                2.0                     2.0            2.0
# 3                                5.0                     5.0            5.0
# 4                                3.0                     3.0            3.0
#
#    Food and drink  Online boarding  Seat comfort  Inflight entertainment  \
# 0               5                3             5                       5
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
df_final[['Flight Distance', 'Overall Delay']] = scaler.fit_transform(df_final[['Flight Distance', 'Overall Delay']])
df_final.head()
# Out:
#     Age  Flight Distance  Inflight wifi service  \
# 0  13.0         0.086632                      3
# 1  25.0         0.041195                      3
# 2  26.0         0.224354                      2
# 3  25.0         0.107229                      2
# 4  61.0         0.036955                      3
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                4.0                     3.0            1.0
# 1                                2.0                     3.0            3.0
# 2                                2.0                     2.0            2.0
# 3                                5.0                     5.0            5.0
# 4                                3.0                     3.0            3.0
#
#    Food and drink  Online boarding  Seat comfort  Inflight entertainment  \
# 0               5                3             5                       5
# ...

# %%
df_final.describe()
# Out:
#                  Age  Flight Distance  Inflight wifi service  \
# count  101399.000000    101399.000000          101399.000000
# mean       39.371039         0.233849               2.729583
# std        15.117242         0.201403               1.327433
# min         7.000000         0.000000               0.000000
# 25%        27.000000         0.077141               2.000000
# 50%        40.000000         0.163772               3.000000
# 75%        51.000000         0.345921               4.000000
# max        85.000000         1.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      101399.000000           101399.000000
# mean                            3.059488                2.756240
# std                             1.525503                1.398689
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# ...

# %% [markdown]
# #### Why min-max normalization?
#
# - Min-max normalization ensures that the values in the Overall Delay feature (or columns) are in between the values 0 and 1.
# - The equation is y = (x – min) / (max – min).
# - Machine learning algorithms perform better when the feature are of similar scale.
# - As seen above, the accuracy score for the scaled dataset is slightly better than the unscaled dataset.

# %% [markdown]
# ## <font color= grey> Linear Regression

# %% [markdown]
# ### Predicting Flight Distance

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error, mean_absolute_error

y_distance = df_final['Flight Distance']
X_distance = df_final.drop(columns='Flight Distance')
X_train_distance, X_test_distance, y_train_distance, y_test_distance = train_test_split(X_distance, y_distance, train_size=0.7, random_state=1806)

# %%
lm = LinearRegression()
lm.fit(X_train_distance, y_train_distance)
# Out:
# LinearRegression()

# %%
mse = mean_squared_error(y_test_distance, lm.predict(X_test_distance))
print(mse)
# Out:
# 0.029559929671880227

# %%
maeTrain = mean_absolute_error(y_train_distance, lm.predict(X_train_distance))
print("Training Set Mean Absolute Error: ", maeTrain)

maeTest = mean_absolute_error(y_test_distance, lm.predict(X_test_distance))
print("Test Set Mean Absolute Error: ", maeTest)
# Out:
# Training Set Mean Absolute Error:  0.13429813806752033
# Test Set Mean Absolute Error:  0.13388365517483786

# %% [markdown]
# #### Feature Selection - Flight Distance

# %%
import numpy as np

feature_model = LinearRegression()
feature_model.fit(X_train_distance, y_train_distance)

# These are the feature labels from our data set
feature_labels = np.array(X_distance.columns)

# Create a numpy array based on the model's feature importances
importance = feature_model.coef_

#Sort the feature labels based on the feature importance rankings from the model
feature_indexes_by_importance = importance.argsort()

# Print each feature label, from most important to least important (reverse order)
for index in feature_indexes_by_importance:
    print("{} - {}".format(feature_labels[index], importance[index]))
# Out:
# Travel_Type - -0.05798534204718451
# Inflight wifi service - -0.010807336368401036
# Inflight service - -0.00285076839371199
# Food and drink - -0.0017791891695419582
# Gender_Code - -0.0017240976217335181
# Baggage handling - -0.0008256902466964375
# Cleanliness - -0.0006413283958070855
# Age - -0.00043837578892749973
# Checkin service - 0.0002238762250657609
# Gate location - 0.0006242617860525808
# On-board service - 0.0008800722987204833
# Departure/Arrival time convenient - 0.0010018388394687954
# Inflight entertainment - 0.0019697316909126424
# Seat comfort - 0.002082037063081054
# Satisfaction_Code - 0.002711342180225028
# Leg room service - 0.004608819642189133
# Ease of Online booking - 0.004695408296246249
# Online boarding - 0.005973367517294261
# Overall Delay - 0.11482616950764368
# is_Loyal - 0.11999469681975326
# Class_Type - 0.1422278321115573

# %% [markdown]
# ### Predicting Overall Delay

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error, mean_absolute_error

y_delay = df_final['Overall Delay']
X_delay = df_final.drop(columns='Overall Delay')
X_train_delay, X_test_delay, y_train_delay, y_test_delay = train_test_split(X_delay, y_delay, train_size=0.7, random_state=1806)

# %%
lm = LinearRegression()
lm.fit(X_train_delay, y_train_delay)
# Out:
# LinearRegression()

# %%
mse = mean_squared_error(y_test_delay, lm.predict(X_test_delay))
print(mse)
# Out:
# 0.00010567662963403273

# %%
maeTrain = mean_absolute_error(y_train_delay, lm.predict(X_train_delay))
print("Training Set Mean Absolute Error: ", maeTrain)

maeTest = mean_absolute_error(y_test_delay, lm.predict(X_test_delay))
print("Test Set Mean Absolute Error: ", maeTest)
# Out:
# Training Set Mean Absolute Error:  0.005327872073551241
# Test Set Mean Absolute Error:  0.0052997981929479914

# %% [markdown]
# #### Feature Selection - Overall Delay

# %%
import numpy as np

feature_model = LinearRegression()
feature_model.fit(X_train_delay, y_train_delay)

# These are the feature labels from our data set
feature_labels = np.array(X_delay.columns)

# Create a numpy array based on the model's feature importances
importance = feature_model.coef_

#Sort the feature labels based on the feature importance rankings from the model
feature_indexes_by_importance = importance.argsort()

# Print each feature label, from most important to least important (reverse order)
for index in feature_indexes_by_importance:
    print("{} - {}".format(feature_labels[index], importance[index]))
# Out:
# Satisfaction_Code - -0.00179669361272602
# Travel_Type - -0.001119235228431736
# Inflight service - -0.0007119779505012631
# Food and drink - -0.000277815155398025
# Seat comfort - -0.000170080087795035
# Class_Type - -0.00014377993644115457
# On-board service - -9.908702047701221e-05
# Inflight wifi service - -4.470149300245242e-05
# Ease of Online booking - -3.157299380451064e-05
# Age - -8.355805046515523e-06
# Departure/Arrival time convenient - 2.680325797484502e-05
# Gate location - 5.0353024861370785e-05
# Checkin service - 5.408959981553084e-05
# Gender_Code - 8.989252223844675e-05
# Online boarding - 0.00012381702875063414
# Inflight entertainment - 0.00014260480536780923
# Cleanliness - 0.0002048096412646369
# Baggage handling - 0.00035863223684562206
# Leg room service - 0.0003659916072606662
# Flight Distance - 0.0004444101138115983
# is_Loyal - 0.0005973523281361537

# %% [markdown]
# ### Predicting Age

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error, mean_absolute_error

y_age = df_final['Age']
X_age = df_final.drop(columns='Age')
X_train_age, X_test_age, y_train_age, y_test_age = train_test_split(X_age, y_age, train_size=0.7, random_state=1806)

# %%
lm = LinearRegression()
lm.fit(X_train_age, y_train_age)
# Out:
# LinearRegression()

# %%
mse = mean_squared_error(y_test_age, lm.predict(X_test_age))
print(mse)
# Out:
# 197.330078911958

# %%
maeTrain = mean_absolute_error(y_train_age, lm.predict(X_train_age))
print("Training Set Mean Absolute Error: ", maeTrain)

maeTest = mean_absolute_error(y_test_age, lm.predict(X_test_age))
print("Test Set Mean Absolute Error: ", maeTest)
# Out:
# Training Set Mean Absolute Error:  11.247510052440047
# Test Set Mean Absolute Error:  11.285808208980491

# %% [markdown]
# #### Feature Selection - Age

# %%
import numpy as np

feature_model = LinearRegression()
feature_model.fit(X_train_age, y_train_age)

# These are the feature labels from our data set
feature_labels = np.array(X_age.columns)

# Create a numpy array based on the model's feature importances
importance = feature_model.coef_

#Sort the feature labels based on the feature importance rankings from the model
feature_indexes_by_importance = importance.argsort()

# Print each feature label, from most important to least important (reverse order)
for index in feature_indexes_by_importance:
    print("{} - {}".format(feature_labels[index], importance[index]))
# Out:
# Overall Delay - -14.225870088428092
# Travel_Type - -3.7878213090396136
# Flight Distance - -2.8885517776717786
# Satisfaction_Code - -1.7230449765232854
# Inflight service - -1.062073982340012
# Cleanliness - -1.0390563121962753
# Food and drink - -0.8443506497648177
# Baggage handling - -0.8021311770123569
# Ease of Online booking - -0.6206009069163604
# Inflight wifi service - -0.5039125324071926
# Checkin service - 0.1619762385617555
# Gate location - 0.26037973729634395
# Leg room service - 0.2639103296823045
# Departure/Arrival time convenient - 0.3509197014547207
# Gender_Code - 0.5933484941134562
# On-board service - 0.7787779327824854
# Inflight entertainment - 0.897788078153581
# Class_Type - 0.9394027817282701
# Seat comfort - 1.2558294014737437
# Online boarding - 1.9518759118248696
# is_Loyal - 10.66546679830349

# %% [markdown]
# - Overall delay and Age are related to each other based on the weights of respective feature selection.
# - Columns kept will be Age, Overall Delay, Gate location, Check-in service, On-board service, Gender_Code.
# - These columns are kept as they are quite significant in predicitng the Overall Delay of the airline.
# - The mean abosulute error for Linear Regression generally less than 12, which means the prediction and model training is good.
# - The difference between these two sets is extremely minimal, which means that the variance is very low. Hence, there is no over-fitting or underfitting of model taking place.

# %% [markdown]
# ## <font color= grey> Logistic Regression

# %% [markdown]
# Provide the description, justification and results of your technique(s) here.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error, mean_absolute_error

y_log = df_final['Satisfaction_Code']
X_log = df_final.drop(columns='Satisfaction_Code')
X_train_log, X_test_log, y_train_log, y_test_log = train_test_split(X_log, y_log, train_size=0.7, random_state=1806)

# %%
lor = LogisticRegression(max_iter=5000, penalty='l2') #elasticnet --> takes a long time to run / l1 --> removes useless features (in case not using)
lor.fit(X_train_log, y_train_log)
# Out:
# LogisticRegression(max_iter=5000)

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_train_log, lor.predict(X_train_log)))
print(accuracy_score(y_test_log, lor.predict(X_test_log)))
# Out:
# 0.8743994702658533
# 0.8756738987508218

# %%
lor.n_iter_
# Out:
# array([623])

# %% [markdown]
# - This means that the maximum iterations needed for Logistic Regression is 523 iterations.

# %% [markdown]
# #### Grid Search

# %%
from sklearn.model_selection import GridSearchCV

model = LogisticRegression(max_iter=623, penalty='l2')

param_grid = {
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
}

gs_cv = GridSearchCV(model, param_grid, n_jobs=-1, verbose=100)

gs_cv.fit(X_train_log, y_train_log)

print(gs_cv.best_params_)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# {'solver': 'liblinear'}

# %% [markdown]
# After Grid Search, the better set of hyper-parameters found is
# - max_iter=623
# - penalty='l2'
# - solver='liblinear'

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_train_log, gs_cv.predict(X_train_log)))
print(accuracy_score(y_test_log, gs_cv.predict(X_test_log)))
# Out:
# 0.8744135589399682
# 0.8755095332018409

# %% [markdown]
# ### Feature Selection

# %%
import numpy as np

feature_model = LogisticRegression(max_iter=2223, penalty='l2', solver='newton-cg')
feature_model.fit(X_train_log, y_train_log)

# These are the feature labels from our data set
feature_labels = np.array(X_log.columns)

# Create a numpy array based on the model's feature importances
importance = feature_model.coef_[0]

#Sort the feature labels based on the feature importance rankings from the model
feature_indexes_by_importance = importance.argsort()

# Print each feature label, from most important to least important (reverse order)
for index in feature_indexes_by_importance:
    print("{} - {:.2f}".format(feature_labels[index], importance[index]))
# Out:
# Overall Delay - -7.69
# Travel_Type - -2.67
# Ease of Online booking - -0.15
# Departure/Arrival time convenient - -0.12
# Flight Distance - -0.05
# Food and drink - -0.02
# Age - -0.01
# Gate location - 0.03
# Gender_Code - 0.03
# Inflight entertainment - 0.06
# Seat comfort - 0.07
# Baggage handling - 0.12
# Inflight service - 0.14
# Cleanliness - 0.21
# Leg room service - 0.26
# On-board service - 0.29
# Checkin service - 0.31
# Inflight wifi service - 0.41
# Online boarding - 0.60
# Class_Type - 0.75
# is_Loyal - 2.01

# %%
X_train_log.head()
# Out:
#         Age  Flight Distance  Inflight wifi service  \
# 64237  55.0         0.193659                      4
# 82410  45.0         0.112480                      5
# 27234  46.0         0.320880                      5
# 51215  58.0         0.016761                      1
# 25262  35.0         0.052100                      3
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# 64237                                5.0                     5.0
# 82410                                5.0                     5.0
# 27234                                5.0                     5.0
# 51215                                1.0                     1.0
# 25262                                4.0                     3.0
#
#        Gate location  Food and drink  Online boarding  Seat comfort  \
# 64237            5.0               4                4             4
# 82410            5.0               2                5             4
# ...

# %% [markdown]
# #### Insights
# - Only selected attribute is used as not all attributes are a determining factor in predicting the predict column.
# - Logistic Regression is used as it can predict a binary outcome (0/1), such as True/False, Yes/No. It is also used to solve classification problems (satisfaction), which is relevant to this dataset where we are fitting new samples into the two category in the predicting column. (Satisifed/Not Satisfied)
# - Overall Delay is a determining factor in predicitng customers' satisfaction as the weight of Overall Delay is the highest at -7.70.
# - {equation pls}
# - Logistic Regression has an accuracy score of approximately 0.88 on the test set, which means that the model trained well and is accurate in prediction.
# - It also has an accuracy score of approximately 0.87 on the test set.
# - With the difference of 0.01 between training and testing dataset, it means that the variance is low and there is no overfitting of model.

# %% [markdown]
# ## <font color= grey> k-means clustering

# %%
df_final.head()
# Out:
#     Age  Flight Distance  Inflight wifi service  \
# 0  13.0         0.086632                      3
# 1  25.0         0.041195                      3
# 2  26.0         0.224354                      2
# 3  25.0         0.107229                      2
# 4  61.0         0.036955                      3
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                4.0                     3.0            1.0
# 1                                2.0                     3.0            3.0
# 2                                2.0                     2.0            2.0
# 3                                5.0                     5.0            5.0
# 4                                3.0                     3.0            3.0
#
#    Food and drink  Online boarding  Seat comfort  Inflight entertainment  \
# 0               5                3             5                       5
# ...

# %%
flight_data_num = df_updated[['Age', 'Flight Distance', 'Overall Delay']]

flight_data_num.head()
# Out:
#     Age  Flight Distance  Overall Delay
# 0  13.0              460           43.0
# 1  25.0              235            7.0
# 2  26.0             1142            0.0
# 3  25.0              562           20.0
# 4  61.0              214            0.0

# %%
from sklearn.preprocessing import StandardScaler

s_scaler = StandardScaler()
scaled_flight_data = s_scaler.fit_transform(flight_data_num)

scaled_flight_data = pd.DataFrame(scaled_flight_data, columns=flight_data_num.columns)
scaled_flight_data.describe()
# Out:
#                 Age  Flight Distance  Overall Delay
# count  1.013990e+05     1.013990e+05   1.013990e+05
# mean  -2.416500e-16    -1.180954e-16  -1.928807e-16
# std    1.000005e+00     1.000005e+00   1.000005e+00
# min   -2.141343e+00    -1.161107e+00  -3.765678e-01
# 25%   -8.183437e-01    -7.780897e-01  -3.765678e-01
# 50%    4.160573e-02    -3.479469e-01  -3.514763e-01
# 75%    7.692553e-01     5.564557e-01  -7.546907e-02
# max    3.018354e+00     3.804083e+00   9.346588e+01

# %%
WCSS = []

for clusters in range(1,10):
    kmeans = KMeans(n_clusters=clusters, init='k-means++',max_iter=300, n_init=10,random_state=1806)
    kmeans.fit(scaled_flight_data)
    WCSS.append(kmeans.inertia_)

plt.plot(range(1,10),WCSS)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
from sklearn.cluster import KMeans

my_kmeans = KMeans(init='random', n_clusters=4, n_init=10, max_iter=300, random_state=1806)
my_kmeans.fit(scaled_flight_data)
# Out:
# KMeans(init='random', n_clusters=4, random_state=1806)

# %%
flight_data_num['Cluster'] = my_kmeans.labels_
# Out:
# C:\Users\haoru\AppData\Local\Temp\ipykernel_24040\2981494654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flight_data_num['Cluster'] = my_kmeans.labels_

# %%
flight_data_num.describe()
# Out:
#                  Age  Flight Distance  Overall Delay        Cluster
# count  101399.000000    101399.000000  101399.000000  101399.000000
# mean       39.371039      1189.022584      30.015493       1.106826
# std        15.117242       997.348306      79.708457       1.141193
# min         7.000000        31.000000       0.000000       0.000000
# 25%        27.000000       413.000000       0.000000       0.000000
# 50%        40.000000       842.000000       2.000000       1.000000
# 75%        51.000000      1744.000000      24.000000       2.000000
# max        85.000000      4983.000000    7480.000000       3.000000

# %%
df_0 = flight_data_num[flight_data_num['Cluster'] == 0]
df_0.describe()
# Out:
#                 Age  Flight Distance  Overall Delay  Cluster
# count  38484.000000     38484.000000   38484.000000  38484.0
# mean      25.149439       744.408741      18.406948      0.0
# std        8.190194       487.374102      34.278357      0.0
# min        7.000000        31.000000       0.000000      0.0
# 25%       20.000000       363.000000       0.000000      0.0
# 50%       25.000000       628.000000       1.000000      0.0
# 75%       32.000000      1012.000000      20.000000      0.0
# max       38.000000      2786.000000     209.000000      0.0

# %%
df_1 = flight_data_num[flight_data_num['Cluster'] == 1]
df_1.describe()
# Out:
#                 Age  Flight Distance  Overall Delay  Cluster
# count  36304.000000     36304.000000   36304.000000  36304.0
# mean      51.929484       695.058286      17.914720      1.0
# std        8.939012       453.388694      33.849992      0.0
# min       39.000000        31.000000       0.000000      1.0
# 25%       44.000000       333.000000       0.000000      1.0
# 50%       51.000000       584.000000       1.000000      1.0
# 75%       58.000000       973.000000      19.000000      1.0
# max       85.000000      2200.000000     204.000000      1.0

# %%
df_2 = flight_data_num[flight_data_num['Cluster'] == 2]
df_2.describe()
# Out:
#                Age  Flight Distance  Overall Delay  Cluster
# count  3906.000000      3906.000000    3906.000000   3906.0
# mean     38.691500      1123.734511     326.942908      2.0
# std      14.521469       907.340068     209.826450      0.0
# min       7.000000        67.000000     161.000000      2.0
# 25%      27.000000       438.000000     219.250000      2.0
# 50%      39.000000       839.500000     273.000000      2.0
# 75%      49.000000      1591.500000     366.000000      2.0
# max      80.000000      3979.000000    7480.000000      2.0

# %%
df_3 = flight_data_num[flight_data_num['Cluster'] == 3]
df_3.describe()
# Out:
#                 Age  Flight Distance  Overall Delay  Cluster
# count  22705.000000     22705.000000   22705.000000  22705.0
# mean      43.512706      2743.676371      17.958732      3.0
# std       11.430479       653.073621      34.680500      0.0
# min        7.000000      1564.000000       0.000000      3.0
# 25%       36.000000      2229.000000       0.000000      3.0
# 50%       44.000000      2608.000000       1.000000      3.0
# 75%       52.000000      3287.000000      18.000000      3.0
# max       85.000000      4983.000000     246.000000      3.0

# %% [markdown]
# - Only numerical attributes can be used.
# - Flight Distance and Overall Delay are the two numeric attributes available in this dataset.
# - 4 clusters was used as the elbow method has proven that any cluster above 4 will have a less significant change to the position of the clusters.
#
# The 4 Clusters:
# - Cluster 0: Median Age is 25. Median Flight Distance is 628. Mean delay is 18.4 min.
# - Cluster 1: Median Age is 51. Median Flight Distance is 584. Mean delay is 17.9 min.
# - Cluster 2: Median Age is 39. Median Flight Distance is 839. Mean delay is 326.9 min.
# - Cluster 3: Median Age is 44. Median Flight Distance is 2608. Mean delay is 17.9 min.
#
# Clusters 0,1 and 3 consists of short delays.
#
# Clusters 0 and 1 consist of short haul flights.
#
# Cluster 0 represents the younger age group.
#
# Cluster 1 represents the older age group.
#
# Both Clusters 2 and 3 consists of middle-aged customers.
#
# Cluster 2 contains extremely long delays, which airline X should be wary of. Moreover it consists of medium-haul flights.
#
# Cluster 3 focuses on long haul flights (long distance flights).

# %% [markdown]
# # <font color= maroon> Recommendations & Conclusion

# %% [markdown]
# The overall problem that could be affecting satisfaction rate is Overall Delay.
#
# - Airline X can offer greater boarding gate convenience for its passengers.
# It would be better if Airline X can allocate boarding gates near the immigration clearence (1) or near the duty free shops (2).
#
# (1) Passengers can conveniently reach the boarding gate without walking for long distance.
#
# (2) Passengers who love to shop at duty free would not need to rush towards further boarding gate areas after immense shopping.
#
# - Airline X can offer mobile application reminders to their passengers on the current status of the aircraft.
# As seen from the feature selection, many passengers who are causing delays are younger passengers.
#
# They could be causing delays due to inexperience of travelling and distractions.
#
# Since, younger generation are more technologically saavy, airline X should offer technological support to their customers where they could rely on a mobile app to know their boarding gate and current stauts of the flight.

# %% [markdown]
# # <font color= maroon> References

# %% [markdown]
# - https://www.sciencedirect.com/topics/computer-science/logistic-regression#:~:text=Logistic%20regression%20is%20a%20process,%2Fno%2C%20and%20so%20on.
# - https://dbpedia.org/page/Flight_length
